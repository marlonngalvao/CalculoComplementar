# %%
# Aluno: Marlon Galvão

from sympy import *
from IPython.display import Image
import numpy as np
import pylab as plt

# %%
Image(filename='questao1.png')

# %%
Image(filename='questao2.png')

# %% [markdown]
# A derivada da função lucro nos dá a taxa de variação do lucro em relação ao nível de produção.
#
# f(x) = - 400x² + 6.800x - 12.000
#
# Derivando:

# %%
x = Symbol('x')
diff(-400*x**2+6800*x-12000,x) #  - 400x² + 6.800x - 12.000 -> f'(x)=-400(2) x + 6800  -> -800x + 6800
# Out:
# 6800 - 800*x

# %%
Então basta calcular o valor de f'(9000)

# %%
y=9000
6800-800*(y)
# Out:
# -7193200

# %%
Image(filename='questao3.png')

# %% [markdown]
# -A criança pesa 34 kg.
# -A criança tem 1m e 20cm de altura.
#
# O objetivo é estimar qual vai ser a variação da área superficial se a criança engorda 1kg, e
# a altura permanecer a mesma.

# %%
def derivada_parcial(funcao,x,y, h=0.01):
    return (funcao(x+h/2,y+h/2)-f(x-h/2,y+h/2)-f(x+h/2,y-h/2)+f(x-h/2,y-h/2))/(h**2)

sw = lambda x:  0.0072 * (x**0.425) * (163**0.725) 
sh = lambda x:  0.0072 * (50**0.425) * (x**0.725)

# 𝑓(𝑥,𝑦)=𝑥∗𝑠𝑒𝑛(𝑦)
# f = lambda x,y: x*np.sin(y)
f = lambda w,h: 0.0072*(w**0.425) * (h**0.725)
d_parcial = derivada_parcial(f,50,163)

print(d_parcial)
# Out:
# 5.7650102469608555e-05
